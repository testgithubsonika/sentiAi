# %%
import torch

print(torch.cuda.is_available())
if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0))
# Out:
# True
# Tesla T4

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys

PROJECT_DIR = "/content/drive/MyDrive/BehavioralAI"

sys.path.append(PROJECT_DIR)

# %%
DATA_DIR = "/content/drive/MyDrive/BehavioralAI/data"

MODELS_DIR = "/content/drive/MyDrive/BehavioralAI/models"

ACCESS_LOGS = f"{DATA_DIR}/access_logs.parquet"

ENTITY_PROFILES = f"{DATA_DIR}/entity_profiles.csv"

# %%
# %cd /content/drive/MyDrive/BehavioralAI
# Out:
# /content/drive/MyDrive/BehavioralAI

# %%
import sklearn

import numpy as np
import pandas as pd
# import torch
print(sklearn.__version__)
# Out:
# 1.6.1

# %%
# !pip install -r requirements-colab.txt --prefer-binary

# %%
# !pip install --upgrade --force-reinstall numpy scipy scikit-learn

# This issue happens due to an **incompatibility between recent versions of NumPy (specifically NumPy 2.x) and SciPy/Scikit-Learn** in Google Colab or Python 3.12 environments. NumPy restructured its internal C-API (`numpy._core`), causing older or mismatched binary builds of Scikit-learn/SciPy to fail when accessing private NumPy attributes like `_blas_supports_fpe`.



### Solution 1: Upgrade NumPy and Scikit-Learn (Recommended)
# Run the following in a notebook cell to upgrade `scikit-learn`, `scipy`, and `numpy` to their latest compatible releases:

# ```bash
# !pip install --upgrade numpy scipy scikit-learn
# Out:
# ...
#   Using cached numpy-2.5.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 7.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.7/16.7 MB 112.3 MB/s eta 0:00:0000:010:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.3/35.3 MB 28.0 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 122.5 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.1/309.1 kB 31.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 461.0/461.0 kB 41.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: threadpoolctl
#     Found existing installation: threadpoolctl 3.6.0
#     Uninstalling threadpoolctl-3.6.0:
#       Successfully uninstalled threadpoolctl-3.6.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.4.6
#     Uninstalling numpy-2.4.6:
#       Successfully uninstalled numpy-2.4.6
# ...

# %%
import pandas as pd

from attack_pipeline import AttackClassificationPipeline

# %%
pipeline = AttackClassificationPipeline(
    entity_profiles_df=profiles_df,
    bilstm_epochs=8,
    random_state=42,
)

# %%
metrics = pipeline.fit(logs_df)

print(metrics["classification_report"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_17702/4214671104.py in <cell line: 0>()
# ----> 1 metrics = pipeline.fit(logs_df)
#       2
#       3 print(metrics["classification_report"])
#
# /content/drive/MyDrive/BehavioralAI/attack_pipeline.py in fit(self, logs_df)
#     198
#     199         iforest_scores = self._score_baseline(logs_df)
# --> 200         bilstm_features = self._fit_bilstm(logs_df)
#     201         features_df = AttackFeatureBuilder.from_dataframe(logs_df, iforest_scores, bilstm_features)
#     202         return self.xgb_classifier.train(features_df)
#
# /content/drive/MyDrive/BehavioralAI/attack_pipeline.py in _fit_bilstm(self, logs_df)
#     150     # -- stage 2: Bi-LSTM sequence features -------------------------------
#     151     def _fit_bilstm(self, logs_df: pd.DataFrame) -> pd.DataFrame:
# ...

# %% [markdown]
# This single line trains:
#
# Isolation Forest
# River HalfSpaceTrees
# Bi-LSTM
# XGBoost automatically

# %%
pipeline.save(MODELS_DIR)

# %%
df = pd.read_csv("models/entity_profiles.csv")

print(df["typical_resources"].head(10))

print(type(df["typical_resources"].iloc[0]))
# Out:
# 0    [np.str_('resource/hr/016'), np.str_('resource...
# 1    [np.str_('resource/customer_db/015'), np.str_(...
# 2    [np.str_('resource/infra/010'), np.str_('resou...
# 3    [np.str_('resource/iot_gateway/009'), np.str_(...
# 4    [np.str_('resource/devops/025'), np.str_('reso...
# 5    [np.str_('resource/infra/015'), np.str_('resou...
# 6    [np.str_('resource/engineering/006'), np.str_(...
# 7    [np.str_('resource/customer_db/025'), np.str_(...
# 8    [np.str_('resource/engineering/021'), np.str_(...
# 9    [np.str_('resource/finance/004'), np.str_('res...
# Name: typical_resources, dtype: object
# <class 'str'>

# %%
from attack_pipeline import AttackClassificationPipeline

pipeline = AttackClassificationPipeline.load_pretrained("models")

print("Loaded successfully")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_13675/812481089.py in <cell line: 0>()
#       1 from attack_pipeline import AttackClassificationPipeline
#       2
# ----> 3 pipeline = AttackClassificationPipeline.load_pretrained("models")
#       4
#       5 print("Loaded successfully")
#
# /content/drive/My Drive/BehavioralAI/attack_pipeline.py in load_pretrained(cls, model_dir, entity_profiles_df, device)
#     295                 )
#     296             entity_profiles_df = pd.read_csv(profiles_path)
# --> 297             entity_profiles_df["typical_resources"] = entity_profiles_df["typical_resources"].apply(ast.literal_eval)
#     298
#     299         behavioral_profiler = (
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4922             args=args,
# ...

# %%
from attack_pipeline import AttackClassificationPipeline

loaded_pipeline = AttackClassificationPipeline.load_pretrained(MODELS_DIR)

print("All models loaded successfully.")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_13675/2884909488.py in <cell line: 0>()
#       1 from attack_pipeline import AttackClassificationPipeline
#       2
# ----> 3 loaded_pipeline = AttackClassificationPipeline.load_pretrained(MODELS_DIR)
#       4
#       5 print("All models loaded successfully.")
#
# /content/drive/My Drive/BehavioralAI/attack_pipeline.py in load_pretrained(cls, model_dir, entity_profiles_df, device)
#     295                 )
#     296             entity_profiles_df = pd.read_csv(profiles_path)
# --> 297             entity_profiles_df["typical_resources"] = entity_profiles_df["typical_resources"].apply(ast.literal_eval)
#     298
#     299         behavioral_profiler = (
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4922             args=args,
# ...
